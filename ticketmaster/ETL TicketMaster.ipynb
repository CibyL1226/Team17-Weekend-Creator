# %% [markdown]
# # AWS Glue Studio Notebook
# ##### You are now running a AWS Glue Studio notebook; To start using your notebook you need to start an AWS Glue Interactive Session.

# %% [markdown]
# #### Optional: Run this cell to see available notebook commands ("magics").

# %%
# %help
# Out:
# # Available Magic Commands
#
# ## Sessions Magic
#
# ----
#     %help                             Return a list of descriptions and input types for all magic commands.
#     %profile            String        Specify a profile in your aws configuration to use as the credentials provider.
#     %region             String        Specify the AWS region in which to initialize a session.
#                                       Default from ~/.aws/config on Linux or macOS,
#                                       or C:\Users\ USERNAME \.aws\config" on Windows.
#     %idle_timeout       Int           The number of minutes of inactivity after which a session will timeout.
#                                       Default: 2880 minutes (48 hours).
#     %timeout            Int           The number of minutes after which a session will timeout.
#                                       Default: 2880 minutes (48 hours).
#     %session_id_prefix  String        Define a String that will precede all session IDs in the format
#                                       [session_id_prefix]-[session_id]. If a session ID is not provided,
#                                       a random UUID will be generated.
#     %status                           Returns the status of the current Glue session including its duration,
#                                       configuration and executing user / role.
#     %session_id                       Returns the session ID for the running session.
#     %list_sessions                    Lists all currently running sessions by ID.
#     %stop_session                     Stops the current session.
#     %glue_version       String        The version of Glue to be used by this session.
#                                       Currently, the only valid options are 2.0, 3.0 and 4.0.
#                                       Default: 2.0.
#     %reconnect          String        Specify a live session ID to switch/reconnect to the sessions.
# ----
#
# ## Selecting Session Types
#
# ----
#     %streaming          String        Sets the session type to Glue Streaming.
#     %etl                String        Sets the session type to Glue ETL.
#     %session_type       String        Specify a session_type to be used. Supported values: streaming and etl.
# ----
#
# ## Glue Config Magic
# *(common across all session types)*
#
# ----
#
#     %%configure         Dictionary    A json-formatted dictionary consisting of all configuration parameters for
#                                       a session. Each parameter can be specified here or through individual magics.
#     %iam_role           String        Specify an IAM role ARN to execute your session with.
#                                       Default from ~/.aws/config on Linux or macOS,
#                                       or C:\Users\%USERNAME%\.aws\config` on Windows.
#     %number_of_workers  int           The number of workers of a defined worker_type that are allocated
#                                       when a session runs.
#                                       Default: 5.
#     %additional_python_modules  List  Comma separated list of additional Python modules to include in your cluster
#                                       (can be from Pypi or S3).
#     %%tags        Dictionary          Specify a json-formatted dictionary consisting of tags to use in the session.
#
#     %%assume_role Dictionary, String  Specify a json-formatted dictionary or an IAM role ARN string to create a session
#                                       for cross account access.
#                                       E.g. {valid arn}
#                                       %%assume_role
#                                       'arn:aws:iam::XXXXXXXXXXXX:role/AWSGlueServiceRole'
#                                       E.g. {credentials}
#                                       %%assume_role
#                                       {
#                                             "aws_access_key_id" : "XXXXXXXXXXXX",
#                                             "aws_secret_access_key" : "XXXXXXXXXXXX",
#                                             "aws_session_token" : "XXXXXXXXXXXX"
#                                        }
# ----
#
#
# ## Magic for Spark Sessions (ETL & Streaming)
#
# ----
#     %worker_type        String        Set the type of instances the session will use as workers.
#     %connections        List          Specify a comma separated list of connections to use in the session.
#     %extra_py_files     List          Comma separated list of additional Python files From S3.
#     %extra_jars         List          Comma separated list of additional Jars to include in the cluster.
#     %spark_conf         String        Specify custom spark configurations for your session.
#                                       E.g. %spark_conf spark.serializer=org.apache.spark.serializer.KryoSerializer
# ----
#
# ## Action Magic
#
# ----
#
#     %%sql               String        Run SQL code. All lines after the initial %%sql magic will be passed
#                                       as part of the SQL code.
#     %matplot      Matplotlib figure   Visualize your data using the matplotlib library.
#                                       E.g.
#                                       import matplotlib.pyplot as plt
#                                       # Set X-axis and Y-axis values
#                                       x = [5, 2, 8, 4, 9]
#                                       y = [10, 4, 8, 5, 2]
#                                       # Create a bar chart
#                                       plt.bar(x, y)
#                                       # Show the plot
#                                       %matplot plt
#     %plotly            Plotly figure  Visualize your data using the plotly library.
#                                       E.g.
#                                       import plotly.express as px
#                                       #Create a graphical figure
#                                       fig = px.line(x=["a","b","c"], y=[1,3,2], title="sample figure")
#                                       #Show the figure
#                                       %plotly fig
#
#
#
# ----

# %% [markdown]
# ####  Run this cell to set up and start your interactive session.

# %%
# %idle_timeout 2880
# %glue_version 5.0
# %worker_type G.1X
# %number_of_workers 5

import sys
from awsglue.transforms import *
from awsglue.utils import getResolvedOptions
from pyspark.context import SparkContext
from awsglue.context import GlueContext
from awsglue.job import Job
from pyspark.sql.functions import explode, col

  
sc = SparkContext.getOrCreate()
glueContext = GlueContext(sc)
spark = glueContext.spark_session
job = Job(glueContext)
# Out:
# You are already connected to a glueetl session 0d3fa75b-4f8a-4fd5-aa5f-0f2c3716f9b1.
#
# No change will be made to the current session that is set as glueetl. The session configuration change will apply to newly created sessions.
# Current idle_timeout is 2880 minutes.
# idle_timeout has been set to 2880 minutes.
# You are already connected to a glueetl session 0d3fa75b-4f8a-4fd5-aa5f-0f2c3716f9b1.
#
# No change will be made to the current session that is set as glueetl. The session configuration change will apply to newly created sessions.
# Setting Glue version to: 5.0
# You are already connected to a glueetl session 0d3fa75b-4f8a-4fd5-aa5f-0f2c3716f9b1.
#
# No change will be made to the current session that is set as glueetl. The session configuration change will apply to newly created sessions.
# Previous worker type: G.1X
# Setting new worker type to: G.1X
# You are already connected to a glueetl session 0d3fa75b-4f8a-4fd5-aa5f-0f2c3716f9b1.
#
# No change will be made to the current session that is set as glueetl. The session configuration change will apply to newly created sessions.
# Previous number of workers: 5
# Setting new number of workers to: 5

# %% [markdown]
# #### Example: Create a DynamicFrame from a table in the AWS Glue Data Catalog and display its schema

# %%
dyf = glueContext.create_dynamic_frame.from_catalog(database='ticketmaster-database', table_name='ticketmasterdata_data')
dyf.printSchema()
# Out:
# root
# |-- name: string
# |-- type: string
# |-- id: string
# |-- test: boolean
# |-- url: string
# |-- locale: string
# |-- images: string
# |-- sales: struct
# |    |-- public: struct
# |    |    |-- startDateTime: string
# |    |    |-- startTBD: boolean
# |    |    |-- startTBA: boolean
# |    |    |-- endDateTime: string
# |    |-- presales: array
# |    |    |-- element: struct
# |    |    |    |-- startDateTime: string
# |    |    |    |-- endDateTime: string
# |    |    |    |-- name: string
# |    |    |    |-- description: string
# |    |    |    |-- url: string
# |    |    |    |-- linkDescriptions: struct
# |    |    |    |    |-- en-nz: string
# |    |    |    |    |-- en-ca: string
# |    |    |    |    |-- en-us: string
# |    |    |    |    |-- pt-br: string
# |    |    |    |    |-- en-au: string
# |    |    |    |    |-- es-us: string
# |    |    |    |    |-- es-br: string
# |    |    |    |    |-- en-mx: string
# |    |    |    |    |-- es-mx: string
# |    |    |    |    |-- fr-ca: string
# |-- dates: struct
# |    |-- start: struct
# |    |    |-- localDate: string
# |    |    |-- localTime: string
# |    |    |-- dateTime: string
# |    |    |-- dateTBD: boolean
# |    |    |-- dateTBA: boolean
# |    |    |-- timeTBA: boolean
# |    |    |-- noSpecificTime: boolean
# |    |-- timezone: string
# |    |-- status: struct
# |    |    |-- code: string
# |    |-- spanMultipleDays: boolean
# |-- classifications: array
# |    |-- element: struct
# |    |    |-- primary: boolean
# |    |    |-- segment: struct
# |    |    |    |-- id: string
# |    |    |    |-- name: string
# |    |    |    |-- levelType: string
# |    |    |-- genre: struct
# |    |    |    |-- id: string
# |    |    |    |-- name: string
# |    |    |    |-- levelType: string
# |    |    |-- subGenre: struct
# |    |    |    |-- id: string
# |    |    |    |-- name: string
# |    |    |    |-- levelType: string
# |    |    |-- type: struct
# |    |    |    |-- id: string
# |    |    |    |-- name: string
# |    |    |    |-- levelType: string
# |    |    |-- subType: struct
# |    |    |    |-- id: string
# |    |    |    |-- name: string
# |    |    |    |-- levelType: string
# |    |    |-- family: boolean
# |-- promoter: struct
# |    |-- id: string
# |    |-- name: string
# |    |-- description: string
# |-- promoters: array
# |    |-- element: struct
# |    |    |-- id: string
# |    |    |-- name: string
# |    |    |-- description: string
# |-- ticketLimit: struct
# |    |-- info: string
# |    |-- id: string
# |-- _embedded: struct
# |    |-- venues: array
# |    |    |-- element: struct
# |    |    |    |-- name: string
# |    |    |    |-- type: string
# |    |    |    |-- id: string
# |    |    |    |-- test: boolean
# |    |    |    |-- url: string
# |    |    |    |-- locale: string
# |    |    |    |-- postalCode: string
# |    |    |    |-- timezone: string
# |    |    |    |-- city: struct
# |    |    |    |    |-- name: string
# |    |    |    |-- state: struct
# |    |    |    |    |-- name: string
# |    |    |    |    |-- stateCode: string
# |    |    |    |-- country: struct
# |    |    |    |    |-- name: string
# |    |    |    |    |-- countryCode: string
# |    |    |    |-- address: struct
# |    |    |    |    |-- line1: string
# |    |    |    |    |-- line2: string
# |    |    |    |-- location: struct
# |    |    |    |    |-- longitude: string
# |    |    |    |    |-- latitude: string
# |    |    |    |-- markets: array
# |    |    |    |    |-- element: struct
# |    |    |    |    |    |-- name: string
# |    |    |    |    |    |-- id: string
# |    |    |    |-- dmas: array
# |    |    |    |    |-- element: struct
# |    |    |    |    |    |-- id: int
# |    |    |    |-- social: struct
# |    |    |    |    |-- twitter: struct
# |    |    |    |    |    |-- handle: string
# |    |    |    |-- boxOfficeInfo: struct
# |    |    |    |    |-- phoneNumberDetail: string
# |    |    |    |    |-- openHoursDetail: string
# |    |    |    |    |-- acceptedPaymentDetail: string
# |    |    |    |    |-- willCallDetail: string
# |    |    |    |-- parkingDetail: string
# |    |    |    |-- generalInfo: struct
# |    |    |    |    |-- childRule: string
# |    |    |    |    |-- generalRule: string
# |    |    |    |-- upcomingEvents: struct
# |    |    |    |    |-- tmr: int
# |    |    |    |    |-- tmc: int
# |    |    |    |    |-- _total: int
# |    |    |    |    |-- _filtered: int
# |    |    |    |    |-- ticketmaster: int
# |    |    |    |    |-- archtics: int
# |    |    |    |    |-- universe: int
# |    |    |    |    |-- veeps: int
# |    |    |    |-- ada: struct
# |    |    |    |    |-- adaPhones: string
# |    |    |    |    |-- adaCustomCopy: string
# |    |    |    |    |-- adaHours: string
# |    |    |    |-- _links: struct
# |    |    |    |    |-- self: struct
# |    |    |    |    |    |-- href: string
# |    |    |    |-- images: array
# |    |    |    |    |-- element: struct
# |    |    |    |    |    |-- ratio: string
# |    |    |    |    |    |-- url: string
# |    |    |    |    |    |-- width: int
# |    |    |    |    |    |-- height: int
# |    |    |    |    |    |-- fallback: boolean
# |    |    |    |-- aliases: array
# |    |    |    |    |-- element: string
# |    |    |    |-- accessibleSeatingDetail: string
# |    |-- attractions: array
# |    |    |-- element: struct
# |    |    |    |-- name: string
# |    |    |    |-- type: string
# |    |    |    |-- id: string
# |    |    |    |-- test: boolean
# |    |    |    |-- url: string
# |    |    |    |-- locale: string
# |    |    |    |-- aliases: array
# |    |    |    |    |-- element: string
# |    |    |    |-- images: array
# |    |    |    |    |-- element: struct
# |    |    |    |    |    |-- ratio: string
# |    |    |    |    |    |-- url: string
# |    |    |    |    |    |-- width: int
# |    |    |    |    |    |-- height: int
# |    |    |    |    |    |-- fallback: boolean
# |    |    |    |    |    |-- attribution: string
# |    |    |    |-- classifications: array
# |    |    |    |    |-- element: struct
# |    |    |    |    |    |-- primary: boolean
# |    |    |    |    |    |-- segment: struct
# |    |    |    |    |    |    |-- id: string
# |    |    |    |    |    |    |-- name: string
# |    |    |    |    |    |    |-- levelType: string
# |    |    |    |    |    |-- genre: struct
# |    |    |    |    |    |    |-- id: string
# |    |    |    |    |    |    |-- name: string
# |    |    |    |    |    |    |-- levelType: string
# |    |    |    |    |    |-- subGenre: struct
# |    |    |    |    |    |    |-- id: string
# |    |    |    |    |    |    |-- name: string
# |    |    |    |    |    |    |-- levelType: string
# |    |    |    |    |    |-- type: struct
# |    |    |    |    |    |    |-- id: string
# |    |    |    |    |    |    |-- name: string
# |    |    |    |    |    |    |-- levelType: string
# |    |    |    |    |    |-- subType: struct
# |    |    |    |    |    |    |-- id: string
# |    |    |    |    |    |    |-- name: string
# |    |    |    |    |    |    |-- levelType: string
# |    |    |    |    |    |-- family: boolean
# |    |    |    |-- upcomingEvents: struct
# |    |    |    |    |-- tmr: int
# |    |    |    |    |-- tmc: int
# |    |    |    |    |-- _total: int
# |    |    |    |    |-- _filtered: int
# |    |    |    |    |-- ticketmaster: int
# |    |    |    |    |-- mfx-no: int
# |    |    |    |-- _links: struct
# |    |    |    |    |-- self: struct
# |    |    |    |    |    |-- href: string
# |    |    |    |-- externalLinks: struct
# |    |    |    |    |-- youtube: array
# |    |    |    |    |    |-- element: struct
# |    |    |    |    |    |    |-- url: string
# |    |    |    |    |-- twitter: array
# |    |    |    |    |    |-- element: struct
# |    |    |    |    |    |    |-- url: string
# |    |    |    |    |-- itunes: array
# |    |    |    |    |    |-- element: struct
# |    |    |    |    |    |    |-- url: string
# |    |    |    |    |-- lastfm: array
# |    |    |    |    |    |-- element: struct
# |    |    |    |    |    |    |-- url: string
# |    |    |    |    |-- spotify: array
# |    |    |    |    |    |-- element: struct
# |    |    |    |    |    |    |-- url: string
# |    |    |    |    |-- facebook: array
# |    |    |    |    |    |-- element: struct
# |    |    |    |    |    |    |-- url: string
# |    |    |    |    |-- wiki: array
# |    |    |    |    |    |-- element: struct
# |    |    |    |    |    |    |-- url: string
# |    |    |    |    |-- instagram: array
# |    |    |    |    |    |-- element: struct
# |    |    |    |    |    |    |-- url: string
# |    |    |    |    |-- musicbrainz: array
# |    |    |    |    |    |-- element: struct
# |    |    |    |    |    |    |-- id: string
# |    |    |    |    |    |    |-- url: string
# |    |    |    |    |-- homepage: array
# |    |    |    |    |    |-- element: struct
# |    |    |    |    |    |    |-- url: string
# |    |    |    |    |-- tiktok: array
# |    |    |    |    |    |-- element: struct
# |    |    |    |    |    |    |-- url: string
# |-- outlets: array
# |    |-- element: struct
# |    |    |-- url: string
# |    |    |-- type: string
# |-- seatmap: string
# |-- ticketing: struct
# |    |-- allInclusivePricing: struct
# |    |    |-- enabled: boolean
# |    |-- id: string
# |    |-- safeTix: struct
# |    |    |-- enabled: boolean
# |    |    |-- inAppOnlyEnabled: boolean
# |-- accessibility: struct
# |    |-- id: string
# |    |-- ticketLimit: int
# |    |-- info: string
# |    |-- url: string
# |    |-- urlText: string
# |-- ageRestrictions: struct
# |    |-- legalAgeEnforced: boolean
# |    |-- id: string
# |    |-- ageRuleDescription: string
# |-- info: string
# |-- priceRanges: array
# |    |-- element: struct
# |    |    |-- type: string
# |    |    |-- currency: string
# |    |    |-- min: double
# |    |    |-- max: double
# |-- products: array
# |    |-- element: struct
# |    |    |-- name: string
# |    |    |-- id: string
# |    |    |-- url: string
# |    |    |-- type: string
# |    |    |-- classifications: array
# |    |    |    |-- element: struct
# |    |    |    |    |-- primary: boolean
# |    |    |    |    |-- segment: struct
# |    |    |    |    |    |-- id: string
# |    |    |    |    |    |-- name: string
# |    |    |    |    |    |-- levelType: string
# |    |    |    |    |-- genre: struct
# |    |    |    |    |    |-- id: string
# |    |    |    |    |    |-- name: string
# |    |    |    |    |    |-- levelType: string
# |    |    |    |    |-- subGenre: struct
# |    |    |    |    |    |-- id: string
# |    |    |    |    |    |-- name: string
# |    |    |    |    |    |-- levelType: string
# |    |    |    |    |-- type: struct
# |    |    |    |    |    |-- id: string
# |    |    |    |    |    |-- name: string
# |    |    |    |    |    |-- levelType: string
# |    |    |    |    |-- subType: struct
# |    |    |    |    |    |-- id: string
# |    |    |    |    |    |-- name: string
# |    |    |    |    |    |-- levelType: string
# |    |    |    |    |-- family: boolean
# |-- doorsTimes: struct
# |    |-- localDate: string
# |    |-- localTime: string
# |    |-- dateTime: string
# |    |-- id: string

# %%
df = dyf.toDF()

# %% [markdown]
# ## Event

# %%
from pyspark.sql.functions import col, element_at, explode_outer

# Start with the root DataFrame (sdf)
df1 = df.select(
    # Extract the venues array as venue_info, along with top-level event fields
    col("_embedded.venues").alias("venue_info"),
    col("name").alias("event_name"),
    col("type").alias("event_type"),
    col("id").alias("event_id"),
    col("url").alias("event_url"),
    col("locale").alias("event_locale"),
    col("sales.public.startDateTime").alias("sales_public_start"),
    col("sales.public.endDateTime").alias("sales_public_end"),
    col("dates.start.localDate").alias("event_date"),
    col("dates.start.localTime").alias("event_time"),
    col("dates.start.dateTime").alias("event_datetime"),
    col("dates.timezone").alias("event_timezone"),
    col("promoter.id").alias("promoter_id"),
    col("promoter.name").alias("promoter_name"),
    element_at(col("classifications"), 1).alias("primary_classification"),
    element_at(col("priceRanges"), 1).alias("primary_priceRange"),
    col("seatmap").alias("seatmap_url"),
    col("doorsTimes.localDate").alias("doors_localDate"),
    col("doorsTimes.localTime").alias("doors_localTime"),
    col("doorsTimes.dateTime").alias("doors_dateTime")
)

# Explode the venues array to get individual venue rows
df2 = df1.withColumn("venue", explode_outer("venue_info"))

# Extract venue_id from the venue struct
df3 = df2.withColumn("venue_id", col("venue.id"))

# Select and flatten all desired fields, including venue_id
flattened_events = df3.select(
    "venue_id",
    "event_name",
    "event_type",
    "event_id",
    "event_url",
    "event_locale",
    "sales_public_start",
    "sales_public_end",
    "event_date",
    "event_time",
    "event_datetime",
    "event_timezone",
    "promoter_id",
    "promoter_name",
    col("primary_classification.primary").alias("classification_primary"),
    col("primary_classification.segment.name").alias("segment_name"),
    col("primary_classification.genre.name").alias("genre_name"),
    col("primary_classification.type.name").alias("classification_type"),
    "seatmap_url",
    "doors_localDate",
    "doors_localTime",
    "doors_dateTime",
    col("primary_priceRange.type").alias("price_type"),
    col("primary_priceRange.currency").alias("price_currency"),
    col("primary_priceRange.min").alias("price_min"),
    col("primary_priceRange.max").alias("price_max")
)

flattened_events.show(10, truncate=False)
flattened_events.printSchema()
# Out:
# +------------+-------------------------------------------+----------+--------------+-------------------------------------------------------------------------------------------------------------------------+------------+--------------------+--------------------+----------+----------+--------------------+----------------+-----------+------------------+----------------------+------------+----------+-------------------+-------------------------------------------------------------------------------------------------+---------------+---------------+--------------------+----------+--------------+---------+---------+
# |venue_id    |event_name                                 |event_type|event_id      |event_url                                                                                                                |event_locale|sales_public_start  |sales_public_end    |event_date|event_time|event_datetime      |event_timezone  |promoter_id|promoter_name     |classification_primary|segment_name|genre_name|classification_type|seatmap_url                                                                                      |doors_localDate|doors_localTime|doors_dateTime      |price_type|price_currency|price_min|price_max|
# +------------+-------------------------------------------+----------+--------------+-------------------------------------------------------------------------------------------------------------------------+------------+--------------------+--------------------+----------+----------+--------------------+----------------+-----------+------------------+----------------------+------------+----------+-------------------+-------------------------------------------------------------------------------------------------+---------------+---------------+--------------------+----------+--------------+---------+---------+
# |KovZpZAJtFaA|Miami Heat vs. Washington Wizards          |event     |vvG1VZb8z9ePVI|https://www.ticketmaster.com/miami-heat-vs-washington-wizards-miami-florida-04-13-2025/event/0D00610E170A5D28            |en-us       |2024-08-16T16:00:00Z|2025-04-13T19:00:00Z|2025-04-13|13:00:00  |2025-04-13T17:00:00Z|America/New_York|695        |NBA REGULAR SEASON|true                  |Sports      |Basketball|Group              |https://mapsapi.tmol.io/maps/geometry/3/event/0D00610E170A5D28/staticImage?type=png&systemId=HOST|NULL           |NULL           |NULL                |standard  |USD           |35.0     |630.0    |
# |KovZpa2gne  |Boston Bruins vs. Chicago Blackhawks       |event     |vvG17ZbuE4768i|https://www.ticketmaster.com/boston-bruins-vs-chicago-blackhawks-boston-massachusetts-04-10-2025/event/010060D9D510742C  |en-us       |2024-07-03T18:00:00Z|2025-04-11T00:00:00Z|2025-04-10|19:00:00  |2025-04-10T23:00:00Z|America/New_York|690        |NHL REGULAR SEASON|true                  |Sports      |Hockey    |Group              |https://mapsapi.tmol.io/maps/geometry/3/event/010060D9D510742C/staticImage?type=png&systemId=HOST|NULL           |NULL           |NULL                |standard  |USD           |75.0     |1565.5   |
# |KovZpZAFaJeA|Colorado Avalanche vs. Detroit Red Wings   |event     |G5vzZbCkD5xSN |https://www.ticketmaster.com/colorado-avalanche-vs-detroit-red-wings-denver-colorado-03-25-2025/event/1E0060E1BB2E2CE3   |en-us       |2024-07-12T16:00:00Z|2025-03-26T03:00:00Z|2025-03-25|19:00:00  |2025-03-26T01:00:00Z|America/Denver  |690        |NHL REGULAR SEASON|true                  |Sports      |Hockey    |Group              |https://mapsapi.tmol.io/maps/geometry/3/event/1E0060E1BB2E2CE3/staticImage?type=png&systemId=HOST|2025-03-25     |18:00:00       |2025-03-26T00:00:00Z|standard  |USD           |89.0     |999.0    |
# |KovZpZA6k7IA|Tampa Bay Lightning vs. Pittsburgh Penguins|event     |vvG1VZb8klgdF4|https://www.ticketmaster.com/tampa-bay-lightning-vs-pittsburgh-penguins-tampa-florida-03-25-2025/event/0D006101ABD43215  |en-us       |2024-08-16T14:00:00Z|2025-03-26T01:00:00Z|2025-03-25|19:00:00  |2025-03-25T23:00:00Z|America/New_York|690        |NHL REGULAR SEASON|true                  |Sports      |Hockey    |Group              |https://mapsapi.tmol.io/maps/geometry/3/event/0D006101ABD43215/staticImage?type=png&systemId=HOST|NULL           |NULL           |NULL                |standard  |USD           |49.25    |1000.25  |
# |KovZpa2M7e  |Chicago Blackhawks vs. Pittsburgh Penguins |event     |vvG18ZbCCrGoLR|https://www.ticketmaster.com/chicago-blackhawks-vs-pittsburgh-penguins-chicago-illinois-04-06-2025/event/040060E39E3117EF|en-us       |2024-09-06T15:00:00Z|2025-04-07T00:00:00Z|2025-04-06|17:00:00  |2025-04-06T22:00:00Z|America/Chicago |690        |NHL REGULAR SEASON|true                  |Sports      |Hockey    |Group              |https://mapsapi.tmol.io/maps/geometry/3/event/040060E39E3117EF/staticImage?type=png&systemId=HOST|NULL           |NULL           |NULL                |standard  |USD           |35.0     |725.0    |
# |KovZpZA6t77A|New York Yankees vs. Baltimore Orioles     |event     |G5vVZbowlaVz5 |https://www.ticketmaster.com/new-york-yankees-vs-baltimore-orioles-bronx-new-york-06-21-2025/event/1D00611CAB274E0B      |en-us       |2024-09-13T14:00:00Z|2025-06-21T18:05:00Z|2025-06-21|13:05:00  |2025-06-21T17:05:00Z|America/New_York|685        |MLB REGULAR SEASON|true                  |Sports      |Baseball  |Group              |https://mapsapi.tmol.io/maps/geometry/3/event/1D00611CAB274E0B/staticImage?type=png&systemId=HOST|NULL           |NULL           |NULL                |standard  |USD           |40.0     |420.0    |
# |KovZpZA6t77A|New York Yankees vs. Toronto Blue Jays     |event     |G5vVZbownXfgv |https://www.ticketmaster.com/new-york-yankees-vs-toronto-blue-bronx-new-york-04-26-2025/event/1D00611CAAF94D41           |en-us       |2024-09-13T14:00:00Z|2025-04-26T18:05:00Z|2025-04-26|13:05:00  |2025-04-26T17:05:00Z|America/New_York|685        |MLB REGULAR SEASON|true                  |Sports      |Baseball  |Group              |https://mapsapi.tmol.io/maps/geometry/3/event/1D00611CAAF94D41/staticImage?type=png&systemId=HOST|NULL           |NULL           |NULL                |standard  |USD           |30.0     |420.0    |
# |KovZ917A25V |Detroit Red Wings vs. Boston Bruins        |event     |vvG1OZbC1J0wiu|https://www.ticketmaster.com/detroit-red-wings-vs-boston-bruins-detroit-michigan-03-29-2025/event/080060E2A6932B0D       |en-us       |2024-08-12T14:00:00Z|2025-03-30T00:00:00Z|2025-03-29|20:00:00  |2025-03-30T00:00:00Z|America/New_York|690        |NHL REGULAR SEASON|true                  |Sports      |Hockey    |Group              |https://mapsapi.tmol.io/maps/geometry/3/event/080060E2A6932B0D/staticImage?type=png&systemId=HOST|NULL           |NULL           |NULL                |standard  |USD           |76.0     |475.25   |
# |KovZpZA6t77A|New York Yankees vs. Houston Astros        |event     |G5vVZbowl3fyp |https://www.ticketmaster.com/new-york-yankees-vs-houston-astros-bronx-new-york-08-08-2025/event/1D00611CAB494E56         |en-us       |2024-09-13T14:00:00Z|2025-08-09T00:05:00Z|2025-08-08|19:05:00  |2025-08-08T23:05:00Z|America/New_York|685        |MLB REGULAR SEASON|true                  |Sports      |Baseball  |Group              |https://mapsapi.tmol.io/maps/geometry/3/event/1D00611CAB494E56/staticImage?type=png&systemId=HOST|NULL           |NULL           |NULL                |standard  |USD           |35.0     |415.0    |
# |KovZpZA6t77A|New York Yankees vs. Athletics             |event     |G5vVZbowl57zE |https://www.ticketmaster.com/new-york-yankees-vs-athletics-bronx-new-york-06-28-2025/event/1D00611CAB2C4E27              |en-us       |2024-09-13T14:00:00Z|2025-06-28T18:05:00Z|2025-06-28|13:05:00  |2025-06-28T17:05:00Z|America/New_York|685        |MLB REGULAR SEASON|true                  |Sports      |Baseball  |Group              |https://mapsapi.tmol.io/maps/geometry/3/event/1D00611CAB2C4E27/staticImage?type=png&systemId=HOST|NULL           |NULL           |NULL                |standard  |USD           |20.0     |420.0    |
# +------------+-------------------------------------------+----------+--------------+-------------------------------------------------------------------------------------------------------------------------+------------+--------------------+--------------------+----------+----------+--------------------+----------------+-----------+------------------+----------------------+------------+----------+-------------------+-------------------------------------------------------------------------------------------------+---------------+---------------+--------------------+----------+--------------+---------+---------+
# only showing top 10 rows
#
# root
#  |-- venue_id: string (nullable = true)
#  |-- event_name: string (nullable = true)
#  |-- event_type: string (nullable = true)
#  |-- event_id: string (nullable = true)
#  |-- event_url: string (nullable = true)
#  |-- event_locale: string (nullable = true)
#  |-- sales_public_start: string (nullable = true)
#  |-- sales_public_end: string (nullable = true)
#  |-- event_date: string (nullable = true)
#  |-- event_time: string (nullable = true)
#  |-- event_datetime: string (nullable = true)
#  |-- event_timezone: string (nullable = true)
#  |-- promoter_id: string (nullable = true)
#  |-- promoter_name: string (nullable = true)
#  |-- classification_primary: boolean (nullable = true)
#  |-- segment_name: string (nullable = true)
#  |-- genre_name: string (nullable = true)
#  |-- classification_type: string (nullable = true)
#  |-- seatmap_url: string (nullable = true)
#  |-- doors_localDate: string (nullable = true)
#  |-- doors_localTime: string (nullable = true)
#  |-- doors_dateTime: string (nullable = true)
#  |-- price_type: string (nullable = true)
#  |-- price_currency: string (nullable = true)
#  |-- price_min: double (nullable = true)
#  |-- price_max: double (nullable = true)

# %% [markdown]
# ## Venue

# %%
venues_df = df.select(explode(col("_embedded.venues")).alias("venue"))
venues_df.printSchema()
# Out:
# root
#  |-- venue: struct (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- test: boolean (nullable = true)
#  |    |-- url: string (nullable = true)
#  |    |-- locale: string (nullable = true)
#  |    |-- postalCode: string (nullable = true)
#  |    |-- timezone: string (nullable = true)
#  |    |-- city: struct (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |-- state: struct (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- stateCode: string (nullable = true)
#  |    |-- country: struct (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- countryCode: string (nullable = true)
#  |    |-- address: struct (nullable = true)
#  |    |    |-- line1: string (nullable = true)
#  |    |    |-- line2: string (nullable = true)
#  |    |-- location: struct (nullable = true)
#  |    |    |-- longitude: string (nullable = true)
#  |    |    |-- latitude: string (nullable = true)
#  |    |-- markets: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |-- dmas: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- id: integer (nullable = true)
#  |    |-- social: struct (nullable = true)
#  |    |    |-- twitter: struct (nullable = true)
#  |    |    |    |-- handle: string (nullable = true)
#  |    |-- boxOfficeInfo: struct (nullable = true)
#  |    |    |-- phoneNumberDetail: string (nullable = true)
#  |    |    |-- openHoursDetail: string (nullable = true)
#  |    |    |-- acceptedPaymentDetail: string (nullable = true)
#  |    |    |-- willCallDetail: string (nullable = true)
#  |    |-- parkingDetail: string (nullable = true)
#  |    |-- generalInfo: struct (nullable = true)
#  |    |    |-- childRule: string (nullable = true)
#  |    |    |-- generalRule: string (nullable = true)
#  |    |-- upcomingEvents: struct (nullable = true)
#  |    |    |-- tmr: integer (nullable = true)
#  |    |    |-- tmc: integer (nullable = true)
#  |    |    |-- _total: integer (nullable = true)
#  |    |    |-- _filtered: integer (nullable = true)
#  |    |    |-- ticketmaster: integer (nullable = true)
#  |    |    |-- archtics: integer (nullable = true)
#  |    |    |-- universe: integer (nullable = true)
#  |    |    |-- veeps: integer (nullable = true)
#  |    |-- ada: struct (nullable = true)
#  |    |    |-- adaPhones: string (nullable = true)
#  |    |    |-- adaCustomCopy: string (nullable = true)
#  |    |    |-- adaHours: string (nullable = true)
#  |    |-- _links: struct (nullable = true)
#  |    |    |-- self: struct (nullable = true)
#  |    |    |    |-- href: string (nullable = true)
#  |    |-- images: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- ratio: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- width: integer (nullable = true)
#  |    |    |    |-- height: integer (nullable = true)
#  |    |    |    |-- fallback: boolean (nullable = true)
#  |    |-- aliases: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- accessibleSeatingDetail: string (nullable = true)

# %%
flattened_venues = venues_df.select(
    col("venue.id").alias("venue_id"),
    col("venue.name").alias("venue_name"),
    col("venue.type").alias("venue_type"),
    col("venue.url").alias("venue_url"),
    col("venue.postalCode").alias("postal_code"),
    col("venue.timezone").alias("venue_timezone"),
    col("venue.city.name").alias("venue_city"),
    col("venue.state.name").alias("venue_state"),
    col("venue.state.stateCode").alias("venue_stateCode"),
    col("venue.country.name").alias("country_name"),
    col("venue.country.countryCode").alias("country_code"),
    col("venue.address.line1").alias("address_line1"),
    col("venue.address.line2").alias("address_line2"),
    col("venue.location.latitude").alias("latitude"),
    col("venue.location.longitude").alias("longitude"),
    element_at(col("venue.markets"), 1).alias("primary_market_struct"),
    element_at(col("venue.dmas"), 1).alias("primary_dma_struct"),
    col("venue.social.twitter.handle").alias("twitter_handle"),
    col("venue.boxOfficeInfo.phoneNumberDetail").alias("phone_number_detail"),
    col("venue.upcomingEvents._total").alias("total_upcoming_events"),
    col("venue.ada.adaPhones").alias("ada_phones"),
    element_at(col("venue.images"), 1).alias("primary_image_struct")
)

# Now, further extract nested fields from the primary structs (if needed)
flattened_venues = flattened_venues.select(
    "venue_id",
    "venue_name",
    "venue_type",
    "venue_url",
    "postal_code",
    "venue_timezone",
    "venue_city",
    "venue_state",
    "venue_stateCode",
    "country_name",
    "country_code",
    "address_line1",
    "address_line2",
    "latitude",
    "longitude",
    col("primary_market_struct.name").alias("primary_market_name"),
    col("primary_market_struct.id").alias("primary_market_id"),
    col("primary_dma_struct.id").alias("primary_dma_id"),
    "twitter_handle",
    "phone_number_detail",
    "total_upcoming_events",
    "ada_phones",
    col("primary_image_struct.url").alias("primary_image_url")
)

flattened_venues.show(10, truncate=False)
flattened_venues.printSchema()
# Out:
# +------------+--------------------+----------+-----------------------------------------------------------------------------+-----------+----------------+----------+-------------+---------------+------------------------+------------+-------------------+-------------+-----------+-------------+---------------------------+-----------------+--------------+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------------------------+------------------------------------------+
# |venue_id    |venue_name          |venue_type|venue_url                                                                    |postal_code|venue_timezone  |venue_city|venue_state  |venue_stateCode|country_name            |country_code|address_line1      |address_line2|latitude   |longitude    |primary_market_name        |primary_market_id|primary_dma_id|twitter_handle|phone_number_detail                                                                                                                                                                                                                                                                                                                                          |total_upcoming_events|ada_phones                                                                                                                 |primary_image_url                         |
# +------------+--------------------+----------+-----------------------------------------------------------------------------+-----------+----------------+----------+-------------+---------------+------------------------+------------+-------------------+-------------+-----------+-------------+---------------------------+-----------------+--------------+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------------------------+------------------------------------------+
# |KovZpZAJtFaA|Kaseya Center       |venue     |https://www.ticketmaster.com/kaseya-center-tickets-miami/venue/106601        |33132      |America/New_York|Miami     |Florida      |FL             |United States Of America|US          |601 Biscayne Blvd  |NULL         |25.78123200|-80.18780500 |Miami                      |15               |200           |@AAarena      |Miami HEAT & Arena Event Sales Information: • Miami HEAT Season Tickets & Partial Plans (786) 777 HOOP • Miami HEAT Group Tickets (786) 777 DUNK • Miami HEAT Premium Seats (Courtside/Flagship/Suites/Loges) (786) 777 4320 • Arena Event Suite Sales (786) 777 1000 • Group Ticket & Fundraising Opportunities for Arena Family Shows (786) 777 4FUN (4386)|152                  |NULL                                                                                                                       |NULL                                      |
# |KovZpa2gne  |TD Garden           |venue     |https://www.ticketmaster.com/td-garden-tickets-boston/venue/8337             |02114      |America/New_York|Boston    |Massachusetts|MA             |United States Of America|US          |100 Legends Way    |NULL         |42.36584100|-71.06072400 |Boston                     |11               |200           |@tdgarden     |General Info Number:(617) 624-1000 Group Sales (only!): (617) 624-1805/1806 Bruins (617) 624-BEAR (Groups = 25+) Celtics (617) 523-3030 (Groups = 20+) Please do not contact Group Sales regarding sold out games!                                                                                                                                           |372                  |NULL                                                                                                                       |https://s1.ticketm.net/dbimages/23259v.jpg|
# |KovZpZAFaJeA|Ball Arena          |venue     |https://www.ticketmaster.com/ball-arena-tickets-denver/venue/246112          |80204      |America/Denver  |Denver    |Colorado     |CO             |United States Of America|US          |1000 Chopper Circle|NULL         |39.74724000|-105.01016600|Denver and More            |6                |200           |NULL          |For more information you can also go to Ball Arena website, www.BallArena.com.                                                                                                                                                                                                                                                                               |156                  |NULL                                                                                                                       |https://s1.ticketm.net/dbimages/22044v.jpg|
# |KovZpZA6k7IA|Amalie Arena        |venue     |https://www.ticketmaster.com/amalie-arena-tickets-tampa/venue/106710         |33602      |America/New_York|Tampa     |Florida      |FL             |United States Of America|US          |401 Channelside Dr |NULL         |27.94274300|-82.45177200 |Tampa                      |21               |200           |NULL          |(813) 301-2500 Amalie Arena Ticket Office (813) 301-6700 Accessible Seating Line                                                                                                                                                                                                                                                                             |177                  |NULL                                                                                                                       |https://s1.ticketm.net/dbimages/16606v.jpg|
# |KovZpa2M7e  |United Center       |venue     |https://www.ticketmaster.com/united-center-tickets-chicago/venue/32882       |60612      |America/Chicago |Chicago   |Illinois     |IL             |United States Of America|US          |1901 W Madison     |NULL         |41.88124412|-87.67427375 |Chicagoland and Northern Il|3                |200           |@unitedcenter |(312) 455-4500 (312) 455-4509 (TTY)                                                                                                                                                                                                                                                                                                                          |223                  |NULL                                                                                                                       |https://s1.ticketm.net/dbimages/22961v.jpg|
# |KovZpZA6t77A|Yankee Stadium      |venue     |https://www.ticketmaster.com/yankee-stadium-tickets-bronx/venue/237572       |10451      |America/New_York|Bronx     |New York     |NY             |United States Of America|US          |1 East 161st Street|NULL         |40.82852370|-73.92762640 |New York/Tri-State Area    |35               |296           |NULL          |NULL                                                                                                                                                                                                                                                                                                                                                         |1093                 |Disabled Services at Yankee Stadium: (718) 579-4510 (voice) or (718) 579-4595 (TTY) \nEmail disabledservices@yankees.com.\n|https://s1.ticketm.net/dbimages/16603v.jpg|
# |KovZpZA6t77A|Yankee Stadium      |venue     |https://www.ticketmaster.com/yankee-stadium-tickets-bronx/venue/237572       |10451      |America/New_York|Bronx     |New York     |NY             |United States Of America|US          |1 East 161st Street|NULL         |40.82852370|-73.92762640 |New York/Tri-State Area    |35               |296           |NULL          |NULL                                                                                                                                                                                                                                                                                                                                                         |1093                 |Disabled Services at Yankee Stadium: (718) 579-4510 (voice) or (718) 579-4595 (TTY) \nEmail disabledservices@yankees.com.\n|https://s1.ticketm.net/dbimages/16603v.jpg|
# |KovZ917A25V |Little Caesars Arena|venue     |https://www.ticketmaster.com/little-caesars-arena-tickets-detroit/venue/66238|48201      |America/New_York|Detroit   |Michigan     |MI             |United States Of America|US          |2645 Woodward      |NULL         |42.34108900|-83.05543400 | Toledo & More"            |7                |266           |NULL          |Box Office Phone Number: (313) 471-7929                                                                                                                                                                                                                                                                                                                      |239                  |NULL                                                                                                                       |https://s1.ticketm.net/dbimages/23263v.jpg|
# |KovZpZA6t77A|Yankee Stadium      |venue     |https://www.ticketmaster.com/yankee-stadium-tickets-bronx/venue/237572       |10451      |America/New_York|Bronx     |New York     |NY             |United States Of America|US          |1 East 161st Street|NULL         |40.82852370|-73.92762640 |New York/Tri-State Area    |35               |296           |NULL          |NULL                                                                                                                                                                                                                                                                                                                                                         |1093                 |Disabled Services at Yankee Stadium: (718) 579-4510 (voice) or (718) 579-4595 (TTY) \nEmail disabledservices@yankees.com.\n|https://s1.ticketm.net/dbimages/16603v.jpg|
# |KovZpZA6t77A|Yankee Stadium      |venue     |https://www.ticketmaster.com/yankee-stadium-tickets-bronx/venue/237572       |10451      |America/New_York|Bronx     |New York     |NY             |United States Of America|US          |1 East 161st Street|NULL         |40.82852370|-73.92762640 |New York/Tri-State Area    |35               |296           |NULL          |NULL                                                                                                                                                                                                                                                                                                                                                         |1093                 |Disabled Services at Yankee Stadium: (718) 579-4510 (voice) or (718) 579-4595 (TTY) \nEmail disabledservices@yankees.com.\n|https://s1.ticketm.net/dbimages/16603v.jpg|
# +------------+--------------------+----------+-----------------------------------------------------------------------------+-----------+----------------+----------+-------------+---------------+------------------------+------------+-------------------+-------------+-----------+-------------+---------------------------+-----------------+--------------+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------------------------+------------------------------------------+
# only showing top 10 rows
#
# root
#  |-- venue_id: string (nullable = true)
#  |-- venue_name: string (nullable = true)
#  |-- venue_type: string (nullable = true)
#  |-- venue_url: string (nullable = true)
#  |-- postal_code: string (nullable = true)
#  |-- venue_timezone: string (nullable = true)
#  |-- venue_city: string (nullable = true)
#  |-- venue_state: string (nullable = true)
#  |-- venue_stateCode: string (nullable = true)
#  |-- country_name: string (nullable = true)
#  |-- country_code: string (nullable = true)
#  |-- address_line1: string (nullable = true)
#  |-- address_line2: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- longitude: string (nullable = true)
#  |-- primary_market_name: string (nullable = true)
#  |-- primary_market_id: string (nullable = true)
#  |-- primary_dma_id: integer (nullable = true)
#  |-- twitter_handle: string (nullable = true)
#  |-- phone_number_detail: string (nullable = true)
#  |-- total_upcoming_events: integer (nullable = true)
#  |-- ada_phones: string (nullable = true)
#  |-- primary_image_url: string (nullable = true)

# %% [markdown]
# #### Example: Write the data in the DynamicFrame to a location in Amazon S3 and a table for it in the AWS Glue Data Catalog

# %%
# Define output paths for events and venues within the new folder
output_path_events = "s3://ticketmasterdata-tae-v1/ticketmasterdata-tae-v1/data_parquet/events"
output_path_venues = "s3://ticketmasterdata-tae-v1/ticketmasterdata-tae-v1/data_parquet/venues"

# Write the flattened events DataFrame to the events subfolder in Parquet format
flattened_events.coalesce(1).write.mode("overwrite").parquet(output_path_events)
print("Events data saved to:", output_path_events)

# Write the flattened venues DataFrame to the venues subfolder in Parquet format
flattened_venues.coalesce(1).write.mode("overwrite").parquet(output_path_venues)
print("Venues data saved to:", output_path_venues)
# Out:
# Events data saved to: s3://ticketmasterdata-tae-v1/ticketmasterdata-tae-v1/data_parquet/events
# Venues data saved to: s3://ticketmasterdata-tae-v1/ticketmasterdata-tae-v1/data_parquet/venues
